# %%
import pandas as pd
root = "https://raw.githubusercontent.com/"
repo = "CSSEGISandData/COVID-19"
folder = "/master/csse_covid_19_data/csse_covid_19_time_series/"
datavs1=(root+repo+folder)
#https://github.com/CSSEGISandData/COVID-19

# %%
recovered_global=datavs1+"time_series_covid19_recovered_global.csv"
confirmed_global=datavs1+"time_series_covid19_confirmed_global.csv"
deaths_global=datavs1+"time_series_covid19_deaths_global.csv"

# %%
pd.read_csv(recovered_global)
# Out:
#     Province/State      Country/Region        Lat       Long  1/22/20  \
# 0              NaN         Afghanistan  33.939110  67.709953        0
# 1              NaN             Albania  41.153300  20.168300        0
# 2              NaN             Algeria  28.033900   1.659600        0
# 3              NaN             Andorra  42.506300   1.521800        0
# 4              NaN              Angola -11.202700  17.873900        0
# ..             ...                 ...        ...        ...      ...
# 251            NaN  West Bank and Gaza  31.952200  35.233200        0
# 252            NaN      Western Sahara  24.215500 -12.885800        0
# 253            NaN               Yemen  15.552727  48.516388        0
# 254            NaN              Zambia -13.133897  27.849332        0
# 255            NaN            Zimbabwe -19.015438  29.154857        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  11/25/20  11/26/20  \
# ...

# %%
pd.read_csv(confirmed_global)
# Out:
#     Province/State      Country/Region        Lat       Long  1/22/20  \
# 0              NaN         Afghanistan  33.939110  67.709953        0
# 1              NaN             Albania  41.153300  20.168300        0
# 2              NaN             Algeria  28.033900   1.659600        0
# 3              NaN             Andorra  42.506300   1.521800        0
# 4              NaN              Angola -11.202700  17.873900        0
# ..             ...                 ...        ...        ...      ...
# 266            NaN  West Bank and Gaza  31.952200  35.233200        0
# 267            NaN      Western Sahara  24.215500 -12.885800        0
# 268            NaN               Yemen  15.552727  48.516388        0
# 269            NaN              Zambia -13.133897  27.849332        0
# 270            NaN            Zimbabwe -19.015438  29.154857        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  11/25/20  11/26/20  \
# ...

# %%
df=pd.read_csv(deaths_global)

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'date'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in set(self, item, value)
# ...
